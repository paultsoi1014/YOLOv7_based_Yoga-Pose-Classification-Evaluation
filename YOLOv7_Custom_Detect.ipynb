# %% [markdown]
# ## YOLOv7 based yoga pose classification

# %% [markdown]
# ### Step 1:  Download YOLOv7 repository from Github and install all requirements

# %%
# !git clone https://github.com/WongKinYiu/yolov7
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 734, done.
# remote: Counting objects: 100% (298/298), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 734 (delta 240), reused 213 (delta 209), pack-reused 436
# Receiving objects: 100% (734/734), 67.50 MiB | 5.60 MiB/s, done.
# Resolving deltas: 100% (361/361), done.

# %%
import os
os.getcwd()
# Out:
# '/Users/paultsoi/Desktop/Machine_Learning_Jupyter/YOLOv5'

# %%
#! pip install -r ./yolov7/requirements.txt
# Out:
# Requirement already satisfied: matplotlib>=3.2.2 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from -r ./yolov7/requirements.txt (line 4)) (3.5.2)
# Requirement already satisfied: numpy>=1.18.5 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from -r ./yolov7/requirements.txt (line 5)) (1.22.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from -r ./yolov7/requirements.txt (line 6)) (4.5.5)
# Requirement already satisfied: Pillow>=7.1.2 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from -r ./yolov7/requirements.txt (line 7)) (9.0.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from -r ./yolov7/requirements.txt (line 8)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from -r ./yolov7/requirements.txt (line 9)) (2.28.1)
# Requirement already satisfied: scipy>=1.4.1 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from -r ./yolov7/requirements.txt (line 10)) (1.9.0)
# Requirement already satisfied: torch!=1.12.0,>=1.7.0 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from -r ./yolov7/requirements.txt (line 11)) (1.12.1)
# Requirement already satisfied: torchvision!=0.13.0,>=0.8.1 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from -r ./yolov7/requirements.txt (line 12)) (0.13.1)
# Requirement already satisfied: tqdm>=4.41.0 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from -r ./yolov7/requirements.txt (line 13)) (4.64.0)
# Requirement already satisfied: protobuf~=3.19.0 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from -r ./yolov7/requirements.txt (line 14)) (3.19.4)
# Requirement already satisfied: tensorboard>=2.4.1 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from -r ./yolov7/requirements.txt (line 17)) (2.9.1)
# Requirement already satisfied: pandas>=1.1.4 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from -r ./yolov7/requirements.txt (line 21)) (1.4.3)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from -r ./yolov7/requirements.txt (line 22)) (0.11.2)
# Requirement already satisfied: ipython in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from -r ./yolov7/requirements.txt (line 34)) (8.4.0)
# Requirement already satisfied: psutil in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from -r ./yolov7/requirements.txt (line 35)) (5.9.1)
# Requirement already satisfied: thop in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from -r ./yolov7/requirements.txt (line 36)) (0.1.1.post2207130030)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r ./yolov7/requirements.txt (line 4)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r ./yolov7/requirements.txt (line 4)) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r ./yolov7/requirements.txt (line 4)) (4.34.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r ./yolov7/requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r ./yolov7/requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r ./yolov7/requirements.txt (line 4)) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from requests>=2.23.0->-r ./yolov7/requirements.txt (line 9)) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from requests>=2.23.0->-r ./yolov7/requirements.txt (line 9)) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from requests>=2.23.0->-r ./yolov7/requirements.txt (line 9)) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from requests>=2.23.0->-r ./yolov7/requirements.txt (line 9)) (2022.6.15)
# Requirement already satisfied: typing_extensions in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from torch!=1.12.0,>=1.7.0->-r ./yolov7/requirements.txt (line 11)) (4.3.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r ./yolov7/requirements.txt (line 17)) (2.2.2)
# Requirement already satisfied: absl-py>=0.4 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r ./yolov7/requirements.txt (line 17)) (1.2.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r ./yolov7/requirements.txt (line 17)) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r ./yolov7/requirements.txt (line 17)) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r ./yolov7/requirements.txt (line 17)) (0.6.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r ./yolov7/requirements.txt (line 17)) (63.4.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r ./yolov7/requirements.txt (line 17)) (2.10.0)
# Requirement already satisfied: wheel>=0.26 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r ./yolov7/requirements.txt (line 17)) (0.37.1)
# Requirement already satisfied: grpcio>=1.24.3 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r ./yolov7/requirements.txt (line 17)) (1.46.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r ./yolov7/requirements.txt (line 17)) (1.8.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from pandas>=1.1.4->-r ./yolov7/requirements.txt (line 21)) (2022.1)
# Requirement already satisfied: pickleshare in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from ipython->-r ./yolov7/requirements.txt (line 34)) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from ipython->-r ./yolov7/requirements.txt (line 34)) (4.8.0)
# Requirement already satisfied: traitlets>=5 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from ipython->-r ./yolov7/requirements.txt (line 34)) (5.3.0)
# Requirement already satisfied: appnope in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from ipython->-r ./yolov7/requirements.txt (line 34)) (0.1.3)
# Requirement already satisfied: stack-data in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from ipython->-r ./yolov7/requirements.txt (line 34)) (0.3.0)
# Requirement already satisfied: backcall in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from ipython->-r ./yolov7/requirements.txt (line 34)) (0.2.0)
# Requirement already satisfied: decorator in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from ipython->-r ./yolov7/requirements.txt (line 34)) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from ipython->-r ./yolov7/requirements.txt (line 34)) (3.0.30)
# Requirement already satisfied: jedi>=0.16 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from ipython->-r ./yolov7/requirements.txt (line 34)) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from ipython->-r ./yolov7/requirements.txt (line 34)) (2.12.0)
# Requirement already satisfied: matplotlib-inline in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from ipython->-r ./yolov7/requirements.txt (line 34)) (0.1.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r ./yolov7/requirements.txt (line 17)) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r ./yolov7/requirements.txt (line 17)) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r ./yolov7/requirements.txt (line 17)) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r ./yolov7/requirements.txt (line 17)) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r ./yolov7/requirements.txt (line 17)) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from jedi>=0.16->ipython->-r ./yolov7/requirements.txt (line 34)) (0.8.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard>=2.4.1->-r ./yolov7/requirements.txt (line 17)) (4.12.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from pexpect>4.3->ipython->-r ./yolov7/requirements.txt (line 34)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->-r ./yolov7/requirements.txt (line 34)) (0.2.5)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->-r ./yolov7/requirements.txt (line 17)) (2.1.1)
# Requirement already satisfied: executing in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from stack-data->ipython->-r ./yolov7/requirements.txt (line 34)) (0.9.1)
# Requirement already satisfied: asttokens in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from stack-data->ipython->-r ./yolov7/requirements.txt (line 34)) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from stack-data->ipython->-r ./yolov7/requirements.txt (line 34)) (0.2.2)
# Requirement already satisfied: zipp>=0.5 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.4.1->-r ./yolov7/requirements.txt (line 17)) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r ./yolov7/requirements.txt (line 17)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/paultsoi/desktop/env/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r ./yolov7/requirements.txt (line 17)) (3.2.0)

# %% [markdown]
# ### Step 2: Start prediction based on pre-loaded yoga pose images
#
# * !python: Loading detect.py file in the yolov7 folder
# * weight: The weight after trained with custom dataset
# * img: Input image size
# * conf: Confidence threshold
# * source: Pre-loaded images or videos (0: webcam; img.jpg: image; vid.mp4: video; path/*.jpg: glob)
#
# #### Return
# * Classified labels
# * Path for the detected images with binding boxes

# %%
predicted = !python ./yolov7/detect.py --weights ./yolov7/best.pt --img 640 --conf 0.1 --source ./datasets/yolo_yoga-3/test/images/000201_jpg.rf.0d82da0cd79710b5c1b4301180af4c09.jpg

# %%
predicted
# Out:
# ['YOLOR 🚀 v0.1-103-g6ded32c torch 1.12.1 CPU',
#  '',
#  '/Users/paultsoi/desktop/env/lib/python3.8/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /Users/runner/work/_temp/anaconda/conda-bld/pytorch_1659484780698/work/aten/src/ATen/native/TensorShape.cpp:2895.)',
#  '  return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]',
#  'Model Summary: 314 layers, 36487166 parameters, 6194944 gradients, 103.2 GFLOPS',
#  "Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.1, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='./datasets/yolo_yoga-3/test/images/000201_jpg.rf.0d82da0cd79710b5c1b4301180af4c09.jpg', update=False, view_img=False, weights=['./yolov7/best.pt'])",
#  'Fusing layers... ',
#  'RepConv.fuse_repvgg_block',
#  'RepConv.fuse_repvgg_block',
#  'RepConv.fuse_repvgg_block',
#  'IDetect.fuse',
#  ' Convert model to Traced-model... ',
#  ' traced_script_module saved! ',
#  ' model is traced! ',
#  '',
#  'tree',
#  'runs/detect/exp4/000201_jpg.rf.0d82da0cd79710b5c1b4301180af4c09.jpg']

# %% [markdown]
# ### Step 3: Extract labels, path after the detection, and plot the result

# %%
import os
label_pred = predicted[-2]
path = os.path.join('./', predicted[-1])
print('classified pose: ', label_pred)
# Out:
# classified pose:  tree

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob(path): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %% [markdown]
# ### Step 4: Define Movenet for pose estimation to evaluate yoga pose

# %%
# Define Movenet for pose estimation
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2

Edges = {
    (0, 1): 'm',
    (0, 2): 'c',
    (1, 3): 'm',
    (2, 4): 'c',
    (0, 5): 'm',
    (0, 6): 'c',
    (5, 7): 'm',
    (7, 9): 'm',
    (6, 8): 'c',
    (8, 10): 'c',
    (5, 6): 'y',
    (5, 11): 'm',
    (6, 12): 'c',
    (11, 12): 'y',
    (11, 13): 'm',
    (13, 15): 'm',
    (12, 14): 'c',
    (14, 16): 'c'
}

# Draw all keypoints/landmarks 
def draw_keypoints(frame, keypoints):
    y, x, z = frame.shape
    shaped = np.squeeze(np.multiply(keypoints, [y,x,1]))

    for kps in shaped:
        kps_y, kps_x, _ = kps
        cv2.circle(frame, (int(kps_x), int(kps_y)), 4, (0,255,0), -1)
    return None

# Plotting the skeleton after collecting all keypoints 
def plot_skeleton(frame, keypoints, edge):
    y, x, c = frame.shape 
    shaped = np.squeeze(np.multiply(keypoints, [y,x,1]))
    
    for edge, _ in edge.items():
        kp_1, kp_2 = edge
        y1, x1, c1 = shaped[kp_1]
        y2, x2, c2 = shaped[kp_2]
        
        cv2.line(frame, (int(x1), int(y1)), (int(x2), int(y2)), (255,0,0), 2)
    return None

# %% [markdown]
# #### Define function to calculate joint angles and set criteria for pose evaluation

# %%
# Calculate joint angle for evaluation
def get_angle(keypoint_1, keypoint_2, keypoint_3):
    a = keypoint_1[0:2]
    b = keypoint_2[0:2]
    c = keypoint_3[0:2]
    
    ba = a-b
    bc = c-b
    
    cosine_angle = np.dot(ba,bc)/(np.linalg.norm(ba)*np.linalg.norm(bc))
    
    angle = np.degrees(np.arccos(cosine_angle))
    
    return angle

def tree_evaluate(angle):
    right_foot_angle = get_angle(angle['right_hip'], angle['right_knee'], angle['right_ankle'])
    left_foot_angle = get_angle(angle['left_hip'], angle['left_knee'], angle['left_ankle'])

    if (right_foot_angle < 45 and left_foot_angle > 170) or (left_foot_angle < 45 and right_foot_angle > 170):
        print('good posture, keep it up')
    else:
        print('raise your foot')

def godness_evaluate(angle):
    right_foot_angle = get_angle(angle['right_hip'], angle['right_knee'], angle['right_ankle'])
    left_foot_angle = get_angle(angle['left_hip'], angle['left_knee'], angle['left_ankle'])
    
    if 110< right_foot_angle < 140 and 110 < left_foot_angle < 140:
        print('good posture, keep it up')
        
    elif right_foot_angle > 140 or left_foot_angle > 140: 
        print('Please bend your knee')
        
    elif right_foot_angle < 110 and left_foot_angle < 110: 
        print('Your knee bend too much')


def pose_evaluation(frame, keypoints, label):
    y, x, c = frame.shape 
    shaped = np.squeeze(np.multiply(keypoints, [y,x,1]))
    
    right_hip = shaped[12] 
    right_knee = shaped[14] 
    right_ankle = shaped[16] 
    left_hip = shaped[11] 
    left_knee = shaped[13]   
    left_ankle = shaped[15]
    
    angle_dict = {'right_hip': right_hip, 'right_knee': right_knee, 'right_ankle': right_ankle,
                  'left_hip': left_hip, 'left_knee': left_knee, 'left_ankle': left_ankle
                 }
    
    if label =='tree':
        tree_evaluate(angle_dict)
    
    elif label == 'godness':
        godness_evaluate(angle_dict)

# %% [markdown]
# #### Main Function

# %%
def movenet(images, label):
    interpreter = tf.lite.Interpreter(model_path='./lite-model_movenet_singlepose_lightning_tflite_float16_4.tflite')
    interpreter.allocate_tensors()
    
    
    cap = cv2.VideoCapture(str(images))
    ret, frame = cap.read()
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    img = frame.copy()
    img = np.expand_dims(img, axis=0)
    img = tf.image.resize_with_pad(img, 192, 192)
    input_image = tf.cast(img, dtype=np.uint8)
    
    # Input and output
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()
    
    interpreter.set_tensor(input_details[0]['index'], np.array(input_image))
    interpreter.invoke()
    keypoints_with_scores = interpreter.get_tensor(output_details[0]['index'])
    
    plot_skeleton(frame, keypoints_with_scores, Edges)
    draw_keypoints(frame, keypoints_with_scores)
    pose_evaluation(frame, keypoints_with_scores, label)
    plt.figure(figsize = (8,8))
    plt.imshow(frame)
    plt.show()
    print("\n")
    return frame, keypoints_with_scores

# %% [markdown]
# ### Step 5: Plot the result with binding box and skeleton, supplemented with yoga pose evaluation comments

# %% [markdown]
# #### For good posture example (tree pose)

# %%
predicted = !python ./yolov7/detect.py --weights ./yolov7/best.pt --img 640 --conf 0.1 --source ./datasets/yolo_yoga-3/test/images/00000088_jpg.rf.b0cdf14c92955ee7839bc46292560524.jpg

# %%
import os
import glob
label_pred = predicted[-2]
path = os.path.join('./', predicted[-1])
print('classified pose: ', label_pred)
# Out:
# classified pose:  tree

# %%
for imageName in glob.glob(path): #assuming JPG
    frame, keypoints_with_scores = movenet(imageName, label_pred)
    print("\n")
# Out:
# INFO: Initialized TensorFlow Lite runtime.
# INFO: Applying 1 TensorFlow Lite delegate(s) lazily.
# 2022-08-15 19:41:59.319395: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-08-15 19:41:59.320012: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M1 Pro
# good posture, keep it up

# %% [markdown]
# #### For bad posture example (tree pose)

# %%
predicted = !python ./yolov7/detect.py --weights ./yolov7/best.pt --img 640 --conf 0.1 --source ./datasets/yolo_yoga-3/test/images/000113_jpg.rf.8306b333ff631cecf217ab95f67d271c.jpg

# %%
import os
label_pred = predicted[-2]
path = os.path.join('./', predicted[-1])
print('classified pose: ', label_pred)
# Out:
# classified pose:  tree

# %%
for imageName in glob.glob(path): #assuming JPG
    frame, keypoints_with_scores = movenet(imageName, label_pred)
    print("\n")
# Out:
# raise your foot
# INFO: Applying 1 TensorFlow Lite delegate(s) lazily.

# %% [markdown]
# #### For good posture example (godness pose)

# %%
predicted = !python ./yolov7/detect.py --weights ./yolov7/best.pt --img 640 --conf 0.1 --source ./datasets/yolo_yoga-3/test/images/00000178_jpg.rf.a150082c6c5123b317beff715ba7bb35.jpg

# %%
import os
label_pred = predicted[-2]
path = os.path.join('./', predicted[-1])
print('classified pose: ', label_pred)
# Out:
# classified pose:  godness

# %%
for imageName in glob.glob(path): #assuming JPG
    frame, keypoints_with_scores = movenet(imageName, label_pred)
    print("\n")
# Out:
# good posture, keep it up
# INFO: Applying 1 TensorFlow Lite delegate(s) lazily.

# %% [markdown]
# ### For bad posture example (godness pose)

# %%
predicted = !python ./yolov7/detect.py --weights ./yolov7/best.pt --img 640 --conf 0.1 --source ./datasets/yolo_yoga-3/test/images/00000132_jpg.rf.0802034a8ef41812269769a39cda715c.jpg

# %%
import os
label_pred = predicted[-2]
path = os.path.join('./', predicted[-1])
print('classified pose: ', label_pred)
# Out:
# classified pose:  godness

# %%
for imageName in glob.glob(path): #assuming JPG
    frame, keypoints_with_scores = movenet(imageName, label_pred)
    print("\n")
# Out:
# Please bend your knee
# INFO: Applying 1 TensorFlow Lite delegate(s) lazily.

# %%
predicted = !python ./yolov7/detect.py --weights ./yolov7/best.pt --img 640 --conf 0.1 --source ./datasets/yolo_yoga-3/test/images/1.jpg

# %%
import os
label_pred = predicted[-2]
path = os.path.join('./', predicted[-1])
print('classified pose: ', label_pred)
# Out:
# classified pose:  godness

# %%
for imageName in glob.glob(path): #assuming JPG
    frame, keypoints_with_scores = movenet(imageName, label_pred)
    print("\n")
# Out:
# Your knee bend too much
# INFO: Applying 1 TensorFlow Lite delegate(s) lazily.
